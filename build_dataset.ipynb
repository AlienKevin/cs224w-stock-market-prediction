# %%
import csv

sp500 = []

with open('sp500/S&P 500 Historical Components & Changes(08-17-2024).csv', 'r') as input:
    reader = csv.reader(input)
    latest = list(reader)[-1][-1]
    # yahoo finance uses - instead of . in symbol names
    sp500 = [name.replace('.', '-') for name in latest.split(',')]

print(len(sp500))
# Out:
# 503

# %%
import yfinance as yf

df = yf.download("SPY AAPL", period="1mo")
df
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price                       Adj Close                   Close              \
# Ticker                           AAPL         SPY        AAPL         SPY
# Date
# 2024-09-25 00:00:00+00:00  226.369995  570.039978  226.369995  570.039978
# 2024-09-26 00:00:00+00:00  227.520004  572.299988  227.520004  572.299988
# 2024-09-27 00:00:00+00:00  227.789993  571.469971  227.789993  571.469971
# 2024-09-30 00:00:00+00:00  233.000000  573.760010  233.000000  573.760010
# 2024-10-01 00:00:00+00:00  226.210007  568.619995  226.210007  568.619995
# 2024-10-02 00:00:00+00:00  226.779999  568.859985  226.779999  568.859985
# 2024-10-03 00:00:00+00:00  225.669998  567.820007  225.669998  567.820007
# 2024-10-04 00:00:00+00:00  226.800003  572.979980  226.800003  572.979980
# 2024-10-07 00:00:00+00:00  221.690002  567.799988  221.690002  567.799988
# 2024-10-08 00:00:00+00:00  225.770004  573.169983  225.770004  573.169983
# ...

# %%
df = yf.download(' '.join(sp500), period="10y")
df
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 10 Failed downloads:
# ['GEHC', 'VLTO', 'KVUE']: YFInvalidPeriodError("%ticker%: Period '10y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']")
# ['CEG', 'CARR', 'OTIS', 'ABNB']: YFInvalidPeriodError("%ticker%: Period '10y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', 'ytd', 'max']")
# ['GEV', 'SOLV']: YFInvalidPeriodError("%ticker%: Period '10y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', 'ytd', 'max']")
# ['SW']: YFInvalidPeriodError("%ticker%: Period '10y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', 'ytd', 'max']")
# Price                       Adj Close                                          \
# Ticker                              A        AAL        AAPL        ABBV ABNB
# Date
# 2014-10-27 00:00:00+00:00   35.544605  37.720184   23.331984   39.992973  NaN
# ...

# %%
df['Adj Close'].dropna(how= "all", axis=1).to_csv('s&p500.csv')
